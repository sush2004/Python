# %% [markdown]
# <a href="https://colab.research.google.com/github/sush2004/Python/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  from datetime import datetime
  e_name = input("Enter employee name")
  e_num = input("Enter employee number")    # should not take special character
  while True:
    try:
      w_end = input("enter a week end date")
      d = datetime.strptime(w_end, '%d/%m/%Y')                                  #stripping time from datetime
      d.strftime("%d/%m/%Y")                                                    #format date
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue
    break
  while True:
    try:
      w_hrs = float(input("Enter number of hours worked"))
      if w_hrs >= 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue
    break

  while True:
    try:
      h_rate = float(input("Enter rate per hour"))
      if h_rate >= 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue 
    break

  if w_hrs > 37.50:
    while True:
      try:
        o_rate = float(input("Enter overtime rate"))
        assert o_rate >0 and o_rate<=2
        #if o_rate > 2:
         # print("Please enter value between 0 and 2")
          #break
        #else:
         # print("please enter value greater than 0")
          #continue
        #break
      except ValueError:
        print("Incorrect format, please enter in correct format")
        continue
      break
    while True:
      try:
        tax = float(input("Enter standard tax rate"))
        if tax > 0:
          break
        else:
          print("please enter value greater than 0")
          continue
        break
      except ValueError:
        print("Incorrect format, please enter in correct format")
        continue
      break
    while True:
      try:
        o_tax = float(input("Enter overtime tax rate"))
        if o_tax > 0:
          break
        else:
          print("please enter value greater than 0")
          continue
        break
      except ValueError:
        print("Incorrect format, please enter in correct format")
        continue
      break
  else:
    while True:
      try:
        tax = float(input("Enter standard tax rate"))
        if tax > 0:
          break
        else:
          print("please enter value greater than 0")
          continue
        break
      except ValueError:
        print("Incorrect format, please enter in correct format")
        continue
      break
# Out:
# Enter employee namesush
# Enter employee number1232a
# enter a week end date1/1/2015
# Enter number of hours worked42.5
# Enter rate per hour10.5
# Enter overtime rate1.5
# Enter standard tax rate20
# Enter overtime tax rate50

# %%
while True:
    try:
      h_rate = float(input("Enter rate per hour"))
      if h_rate >= 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue 
    break

# %%
while True:
    try:
      w_hrs = float(input("Enter number of hours worked"))
      if w_hrs >= 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue
    break
if w_hrs > 37.50:
  while True:
    try:
      o_rate = float(input("Enter overtime rate")) 
      if o_rate > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue
    break
  while True:
    try:
      tax = float(input("Enter standard tax rate"))
      if tax > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue
    break
  while True:
    try:
      o_tax = float(input("Enter overtime tax rate"))
      if o_tax > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue
    break
else:
  while True:
    try:
      tax = float(input("Enter standard tax rate"))
      if tax > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except ValueError:
      print("Incorrect format, please enter in correct format")
      continue
    break

# %%
def std_w_hrs():
  tot = w_hrs * h_rate #total pay calculation
  t_tax = tot * (tax/100)    # tax on total income
  t_ded = sum([t_tax])       # total deduction
  net = tot - t_ded          # net pay calculation  

  print("Hours (normal) {0:10} {1:8} {2:7} Tax @{3:3}% {4:3} ".format(w_hrs,h_rate,tot,tax,t_ded))
  print("\n{0:20} Total pay: {1:26}".format(' ',tot))
  print("{0:20} Total deductions: {1:19}".format(' ',t_ded))
  print("{0:20} Net pay: {1:28}".format(' ', net))

def ovt_w_hrs():
   o_hrs = w_hrs - 37.50   #overtime hours calculation
   w_pay = 37.5 * h_rate   # normal weekly pay
   o_pay = o_hrs * (o_rate) #overtime pay calculation
   tot = round(sum([w_pay,o_pay]),2) 
   w_pay_tax = round(w_pay*(tax/100),2) # tax on normal shift hours
   o_pay_tax = round(o_pay*(o_tax/100),2) #tax on overtime shift hours
   t_ded = round(sum([w_pay_tax,o_pay_tax]),2)
   net = round(tot - t_ded,2)  #net pay calculation

   print("Hours (normal) {0:10} {1:8} {2:7} Tax @{3:3}% {4:3} ".format(37.50, h_rate,w_pay,tax,w_pay_tax))
   print("Hours (overtime) {0:8} {1:8} {2:7} Tax @{3:3}% {4:3} ".format(o_hrs,o_rate,o_pay,o_tax,o_pay_tax))
   print("\n{0:20} Total pay: {1:27} ".format(' ',tot))
   print("{0:20} Total deductions: {1:20}".format(' ',t_ded))
   print("{0:20} Net pay: {1:29}".format(' ',net))

# %%
from datetime import datetime

def payslip():
  e_name = input("Enter Employee Name")
  e_num = input("Enter employee Number")                                        # should not take special character
  while True:                                                                   #condition checking for correct date input
    try:
      w_end = input("enter a week end date(dd/mm/yyyy)")
      d = datetime.strptime(w_end, '%d/%m/%Y')                                  #stripping time from datetime
      w_end = d.strftime('%d/%m/%Y')                                                    #format date
    except:
      print("Incorrect format, please enter in correct format")
      continue
    break
  while True:
    try:
      w_hrs = float(input("Enter number of hours worked"))
      if w_hrs > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except:
      print("Incorrect input, please enter again")
      continue
    break

  while True:
    try:
      h_rate = float(input("Enter hourly rate"))
      if h_rate >= 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except:
      print("Incorrect input, please enter again")
      continue 
    break

  while True:
    try:
      tax = int(input("Enter standard tax rate"))
      if tax > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except:
      print("Incorrect input, please enter again")
      continue
    break
  
  print("\n\n{:30} PAYSLIP".format(' '))            
  print("WEEK ENDING", w_end)
  print("Employee:", e_name)
  print("Employee Number:", e_num)
  print("{0:20} Earnings {1:13} Deductions".format(' ',' '))
  print("{0:20} Hours {1:2} Rate {2:1} Total".format(' ',' ',' '))

  if w_hrs <=37.5:
    std_w_hrs(w_hrs,h_rate,tax)
  else:
    ovt_w_hrs(w_hrs,h_rate,o_rate,tax,o_tax)
payslip()
  
def std_w_hrs(w_hrs,h_rate,tax):
  while True:
    try:
      tax = int(input("Enter standard tax rate"))
      if tax > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except:
      print("Incorrect input, please enter again")
      continue
    break
  tot = w_hrs * h_rate #total pay calculation
  t_tax = tot * (tax/100)    # tax on total income
  #t_ded = sum(t_tax)         # total deduction
  net = tot - t_tax          # net pay calculation  

  print("Hours (normal) {0:11,.2f} {1:8,.2f} {2:7,.2f} Tax @ {3:3}% {4:3,.2f} ".format(w_hrs,h_rate,tot,tax,t_tax))
  print("\n{0:20} Total pay: {1:29,.2f}".format(' ',tot))
  print("{0:20} Total deductions: {1:22,.2f}".format(' ',t_tax))
  print("{0:20} Net pay: {1:31,.2f}".format(' ', net))
  
def ovt_w_hrs(w_hrs,h_rate,o_rate,tax,o_tax):
  while True:
    try:
      o_rate = float(input("Enter overtime rate")) 
      if o_rate > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except:
      print("Incorrect input, please enter again")
      continue
    break
  while True:
    try:
      o_tax = int(input("Enter overtime tax rate"))
      if o_tax > 0:
        break
      else:
        print("please enter value greater than 0")
        continue
      break
    except:
      print("Incorrect input, please enter again")
      continue
    break
  o_hrs = w_hrs - 37.50   #overtime hours calculation
  w_pay = 37.5 * h_rate   # normal weekly pay
  ot_rate = o_rate * h_rate
  o_pay = o_hrs * (ot_rate) #overtime pay calculation
  tot = round(sum([w_pay,o_pay]),2) 
  w_pay_tax = round(w_pay*(tax/100),2) # tax on normal shift hours
  o_pay_tax = round(o_pay*(o_tax/100),2) #tax on overtime shift hours
  t_ded = round(sum([w_pay_tax,o_pay_tax]),2)
  net = round((tot - t_ded),2)  #net pay calculation

  print("Hours (normal) {0:11,.2f} {1:8,.2f} {2:7,.2f} Tax @ {3:3}% {4:3,.2f} ".format(37.50,h_rate,w_pay,tax,w_pay_tax))
  print("Hours (overtime) {0:8,.2f} {1:9,.2f} {2:7,.2f} Tax @ {3:3}% {4:4,.2f} ".format(o_hrs,ot_rate,o_pay,o_tax,o_pay_tax))
  print("\n{0:20} Total pay: {1:29,.2f} ".format(' ',tot))
  print("{0:20} Total deductions: {1:22,.2f}".format(' ',t_ded))
  print("{0:20} Net pay: {1:31,.2f}".format(' ',net))



'''
def main():
  w_hrs,h_rate,o_rate,tax,o_tax=character()
  
  if w_hrs>37.5:
    ovt_w_hrs()
  else:
    std_w_hrs()
print("{:>10} {:>20}".format(format(a,'.2f'),format(b,'.2f'))
main()'''
#main()
# Out:
# Enter Employee Namesusant
# Enter employee Numbersdcs234
# enter a week end date(dd/mm/yyyy)1/1/2015
# Enter number of hours worked42.5
# Enter hourly rate10.5
# Enter standard tax rate20
#
#
#                                PAYSLIP
# WEEK ENDING 01/01/2015
# Employee: susant
# Employee Number: sdcs234
#                      Earnings               Deductions
#                      Hours    Rate   Total
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5fda00aa4c60> in <module>()
#      66   else:
#      67     ovt_w_hrs(w_hrs,h_rate,o_rate,tax,o_tax)
# ---> 68 payslip()
#      69
#      70 def std_w_hrs(w_hrs,h_rate,tax):
#
# <ipython-input-4-5fda00aa4c60> in payslip()
#      65     std_w_hrs(w_hrs,h_rate,tax)
#      66   else:
# ---> 67     ovt_w_hrs(w_hrs,h_rate,o_rate,tax,o_tax)
#      68 payslip()
#      69
#
# NameError: name 'o_rate' is not defined

# %%
print("{:>10} {:>20}".format(format(5,'.2f'),format(10,'.2f')))
# Out:
#       5.00                10.00

# %%
print("{0:10,.2f} {1:20,.2f}".format(5,10),'.2f')
# Out:
#       5.00                10.00

# %%
print("{:10}".format(10,'.2f'))
# Out:
#         10

# %%
tot = round(sum([11.44,12.2552]),2)
print(tot)
# Out:
# 23.7

# %%
 w_end = input("enter a week end date(dd/mm/yyyy)")
 d = datetime.strptime(w_end, '%d/%m/%Y')                                  #stripping time from datetime
 d.strftime('%d/%m/%Y')

# %%
def add_contact():
  print("Add contact")
  name = input("Name: ")
  if name.title() in book:
    print("The contact already exists :",book[name.title()])
  else:
    while True:
      phone = input("number: ")
      try:
        phone = int(phone)
        if phone > 0:           #condition to check for positive integers
          book[name.title()] = phone
          print("{} has been added successfully to the phonebook".format(name.title()))
        else:
          print("that's not correct input, please try again :")
          continue
      except:
        print("please enter number/integer value.")
        continue
      break
         
def delete_contact():
  print("Delete contact")
  name = input("Name: ")
  if name.title() in book:
    del book[name.title()]
    print("The contact has been deleted successfully")
  else:
    print(name.title(), "was not found in the phonebook")

def update_contact():
  print("Update contact")
  name = input("Name: " )
  if name.title() in book:
    while True:
      option = input("Do you want to update name(yes/no) :")
      try:
        assert option.title() == 'Yes' or option.title() == 'No'                #
      except:
        print("please enter correct option(yes/no)")
        continue
      break
    if option.title() == 'Yes':                                                 #title() used for case sensitive user input
      up_name = input("Enter new name for the contact")                         #user inputting updated name in contact
      book[up_name.title()] = book.pop(name.title())
      print("{} has been updated in the phonebook".format(up_name.title()))
    else:
      while True:
        option = input("Do you want to update number(yes/no) :")
        try:
          assert option.title() == 'Yes' or option.title() == 'No'
        except:
          print("please enter correct option(yes/no)")
          continue
        break
      if option.title() == 'Yes':
          while True:
            phone = int(input("Enter new phone number for the contact"))
            try:
              phone = int(phone)
              if phone > 0:
                book.update({name.title():phone})
                print("phone number for {} has been updated".format(name.title()))
              else:
                print("that's not correct input, please try again :")
                continue
            except:
              print("please enter number/integer value.")
              continue
            break
      else:
        print("Thank you for using phonebook")
  else:
    print(name.title(), "was not found")

def search_contact():
  print("Search contact")
  name = input("Name: ")
  phone = input
  if name.title() in book:
    print("The number linked to the contact is", book[name.title()])
  else:
    print(name.title(), "was not found")
    while True:
      option = input("Do you want add the contact? (yes/no)")
      try:
        assert option.title() == 'Yes' or option.title() == 'No'
      except:
        print("please enter correct option(yes/no)")
        continue
      break
    if option.title() =='Yes':
      add_contact()  
    else:
      print("Thank you for using phonebook")

def MYPY():
  print("###############################\n MYPY PHONE BOOK \n###############################")
  print('1. Add New Entry')
  print('2. Delete Entry')
  print('3. Update Entry')
  print('4. Lookup Number')
  print('5. Quit')
book = {}
MYPY()
menu_choice = 0
#while menu_choice in range(1,6):
while menu_choice!=5:  
  while True:
    menu_choice = input("Type in a number (1-5): ")
    try:
      menu_choice=int(menu_choice)
      assert menu_choice in range(1,6)
    except:
      print('Enter integer value from 1-5')
      continue
    break
  if menu_choice == 1:
    add_contact()
  elif menu_choice == 2:
    delete_contact()
  elif menu_choice == 3:
    update_contact()
  elif menu_choice == 4:
    search_contact()
  elif menu_choice == 5:
    print("Thank you for using MYPY phone book system")
  elif menu_choice!=5:
    MYPY()
# Out:
# ###############################
#  MYPY PHONE BOOK
# ###############################
# 1. Add New Entry
# 2. Delete Entry
# 3. Update Entry
# 4. Lookup Number
# 5. Quit
# Type in a number (1-5): 1
# Add contact
# Name: sush
# number: 123
# Sush has been added successfully to the phonebook
# Type in a number (1-5): 5
# Thank you for using MYPY phone book system

# %%
from datetime import datetime
#function calling(need to break it down more), o_time_rate need to check.
def payslip():                                                                  # defining main function
  e_name = input("Enter employee name")
  e_num = input("\nEnter employee number")                                      #should not take special character
  while True:                                                                   #condition checking for correct date input
    try:
      w_end = input("\nEnter week end date(dd/mm/yyyy) :")
      d = datetime.strptime(w_end, '%d/%m/%Y')                                  #stripping time from datetime
      w_end = d.strftime("%d/%m/%Y")                                                    #date format *** need to check format
    except:
      print("Incorrect date format, please enter in correct format")
      continue
    break
  while True:
    try:
      w_hrs = float(input("\nEnter number of hours worked"))
      if w_hrs > 0:
        break
      else:
        print("Please enter value greater than 0")
        continue
      break
    except:
      print("Incorrect input, please enter again")
      continue
    break

  while True:
    try:
      h_rate = float(input("\nEnter hourly rate :"))
      if h_rate >= 0:
        break
      else:
        print("Please enter value greater than 0")
        continue
      break
    except:
      print("Incorrect input, please enter numeric value")
      continue 
    break

  if w_hrs > 37.50:
    while True:
      try:
        o_rate = float(input("Enter overtime rate")) 
        if o_rate > 0:
          break
        else:
          print("please enter value greater than 0")
          continue
        break
      except:
        print("Incorrect input, please enter again")
        continue
      break
    while True:
      try:
        tax = int(input("Enter standard tax rate"))
        if tax > 0:
          break
        else:
          print("please enter value greater than 0")
          continue
        break
      except:
        print("Incorrect input, please enter again")
        continue
      break
    while True:
      try:
        o_tax = int(input("Enter overtime tax rate"))
        if o_tax > 0:
          break
        else:
          print("please enter value greater than 0")
          continue
        break
      except:
        print("Incorrect input, please enter again")
        continue
      break
  else:
    while True:
      try:
        tax = int(input("Enter standard tax rate"))
        if tax > 0:
          break
        else:
          print("please enter value greater than 0")
          continue
        break
      except:
        print("Incorrect input, please enter again")
        continue
      break
  print("\n\n{:30} PAYSLIP".format(' '))            
  print("WEEK ENDING", w_end)
  print("Employee:", e_name)
  print("Employee Number:", e_num.upper())
  print("{0:20} Earnings {1:13} Deductions".format(' ',' '))
  print("{0:20} Hours {1:2} Rate {2:1} Total".format(' ',' ',' '))
  if w_hrs <=37.5:
    std_w_hrs(w_hrs,h_rate,tax)
  else:
    ovt_w_hrs(w_hrs,h_rate,o_rate,tax,o_tax)
  
def std_w_hrs(w_hrs,h_rate,tax):
  tot = w_hrs * h_rate                                                          #total pay calculation
  t_tax = tot * (tax/100)                                                       #total tax/deduction on total pay
  net = tot - t_tax                                                             #net pay calculation  

  print("Hours (normal) {0:11,.2f} {1:8,.2f} {2:7,.2f} Tax @ {3:2}% {4:3,.2f} ".format(w_hrs,h_rate,tot,tax,t_tax))
  print("\n{0:20} Total pay: {1:27,.2f}".format(' ',tot))
  print("{0:20} Total deductions: {1:20,.2f}".format(' ',t_tax))
  print("{0:20} Net pay: {1:29,.2f}".format(' ', net))
  
def ovt_w_hrs(w_hrs,h_rate,o_rate,tax,o_tax):
  o_hrs = w_hrs - 37.50                                                         #overtime hours calculation
  w_pay = 37.5 * h_rate                                                         #normal weekly pay
  ot_rate = o_rate * h_rate
  o_pay = o_hrs * (ot_rate)                                                     #overtime pay calculation
  tot = round(sum([w_pay,o_pay]),2)                                             #sum of standard weekly and overtime pay
  w_pay_tax = round(w_pay*(tax/100),2)                                          #tax on normal shift hours
  o_pay_tax = round(o_pay*(o_tax/100),2)                                        #tax on overtime shift hours
  t_ded = round(sum([w_pay_tax,o_pay_tax]),2)
  net = round((tot - t_ded),2)                                                  #net pay calculation

  print("Hours (normal) {0:11,.2f} {1:8,.2f} {2:7,.2f} Tax @ {3:2}% {4:3,.2f} ".format(37.50,h_rate,w_pay,tax,w_pay_tax))
  print("Hours (overtime) {0:8,.2f} {1:9,.2f} {2:7,.2f} Tax @ {3:2}% {4:4,.2f} ".format(o_hrs,ot_rate,o_pay,o_tax,o_pay_tax))
  print("\n{0:20} Total pay: {1:27,.2f} ".format(' ',tot))
  print("{0:20} Total deductions: {1:20,.2f}".format(' ',t_ded))
  print("{0:20} Net pay: {1:29,.2f}".format(' ',net))

payslip()
# Out:
# Enter employee namesushant
#
# Enter employee number124aa
#
# Enter week end date(dd/mm/yyyy) :1/1/2015
#
# Enter number of hours worked36
#
# Enter hourly rate :10.5
# Enter standard tax rate20
#
#
#                                PAYSLIP
# WEEK ENDING 01/01/2015
# Employee: sushant
# Employee Number: 124AA
#                      Earnings               Deductions
#                      Hours    Rate   Total
# Hours (normal)       36.00    10.50  378.00 Tax @ 20% 75.60
#
#                      Total pay:                      378.00
#                      Total deductions:                75.60
#                      Net pay:                        302.40

# %%
print(book)
def search_contact():
  print("Search contact")
  while True:
    search = input("Do you want to search contact by name or number")
    try:
      assert search.title() == "Name" or search.title() == "Number"
      if search.title() =='Name':
        name = input("Name: ")
        phone = input
        if name.title() in book:
          print("The number linked to the contact is", book[name.title()])

        else:
          print(name.title(), "was not found")
          while True:
            option = input("Do you want add the contact? (yes/no)")
            try:
              assert option.title() == 'Yes' or option.title() == 'No'
            except:
              print("please enter correct option(yes/no)")
              continue
            break
          if option.title() =='Yes':
            add_contact()  
          else:
            print("Thank you for using phonebook")
       
      else:
        phone = input("Number:")
        if phone in book:
          print("Contact linked to the phone is", book[phone])
          
        else:
          print(name.title(), "was not found")
          while True:
            option = input("Do you want add the contact? (yes/no)")
            try:
              assert option.title() == 'Yes' or option.title() == 'No'
            except:
              print("please enter correct option(yes/no)")
              continue
            break
          if option.title() =='Yes':
              add_contact()  
          else:
              print("Thank you for using phonebook")
        
    except:
      print("Please enter correct choice(Name/Number")
      continue
    break

  
search_contact()
# Out:
# {'Sush': 123}
# Search contact
# Do you want to search contact by name or numbernumber
# Number:123
# Please enter correct choice(Name/Number
# Do you want to search contact by name or numbernumber
# Number:123
# Please enter correct choice(Name/Number
# Do you want to search contact by name or numbername
# Name: sush
# The number linked to the contact is 123
